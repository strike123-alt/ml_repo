# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
blobs = pd.read_csv(r'D:\Data Science\udemy\Notebooks\DATA\cluster_blobs.csv')

# %%
blobs.head()
# Out:
#          X1        X2
# 0  4.645333  6.822294
# 1  4.784032  6.422883
# 2 -5.851786  5.774331
# 3 -7.459592  6.456415
# 4  4.918911  6.961479

# %%
sns.scatterplot(data = blobs, x = 'X1', y = 'X2')
plt.show()

# %%
moons = pd.read_csv(r'D:\Data Science\udemy\Notebooks\DATA\cluster_moons.csv')

# %%
moons.head()
# Out:
#          X1        X2
# 0  0.674362 -0.444625
# 1  1.547129 -0.239796
# 2  1.601930 -0.230792
# 3  0.014563  0.449752
# 4  1.503476 -0.389164

# %%
sns.scatterplot(data = moons, x = 'X1', y = 'X2')
plt.show()

# %%
circles =  pd.read_csv(r'D:\Data Science\udemy\Notebooks\DATA\cluster_circles.csv')

# %%
circles.head()
# Out:
#          X1        X2
# 0 -0.348677  0.010157
# 1 -0.176587 -0.954283
# 2  0.301703 -0.113045
# 3 -0.782889 -0.719468
# 4 -0.733280 -0.757354

# %%
sns.scatterplot(data = circles, x = 'X1', y = 'X2')
plt.show()

# %%
def display_categories(model, data):
    labels = model.fit_predict(data)
    sns.scatterplot(data = data, x = 'X1', y = 'X2', hue=labels, palette='Set1')
    plt.show()

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters = 3)

# %%
display_categories(model, blobs)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
model = KMeans(n_clusters = 2)

# %%
display_categories(model, moons)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
display_categories(model, circles)
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.cluster import DBSCAN

# %%
help(DBSCAN)
# Out:
# Help on class DBSCAN in module sklearn.cluster._dbscan:
#
# class DBSCAN(sklearn.base.ClusterMixin, sklearn.base.BaseEstimator)
#  |  DBSCAN(eps=0.5, *, min_samples=5, metric='euclidean', metric_params=None, algorithm='auto', leaf_size=30, p=None, n_jobs=None)
#  |
#  |  Perform DBSCAN clustering from vector array or distance matrix.
#  |
#  |  DBSCAN - Density-Based Spatial Clustering of Applications with Noise.
#  |  Finds core samples of high density and expands clusters from them.
#  |  Good for data which contains clusters of similar density.
#  |
#  |  Read more in the :ref:`User Guide <dbscan>`.
#  |
#  |  Parameters
#  |  ----------
#  |  eps : float, default=0.5
#  |      The maximum distance between two samples for one to be considered
#  |      as in the neighborhood of the other. This is not a maximum bound
#  |      on the distances of points within a cluster. This is the most
#  |      important DBSCAN parameter to choose appropriately for your data set
# ...

# %%
model = DBSCAN()

# %%
display_categories(model, blobs)

# %%
model = DBSCAN(eps=0.15)
display_categories(model, moons)

# %%
model = DBSCAN(eps=0.15)
display_categories(model, circles)
