# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
two_blobs = pd.read_csv(r'D:\Data Science\udemy\Notebooks\DATA\cluster_two_blobs.csv')

# %%
two_blobs.head()
# Out:
#          X1        X2
# 0  0.046733  1.765120
# 1 -8.994134 -6.508186
# 2  0.650539  1.264533
# 3 -9.501554 -6.736493
# 4  0.057050  0.188215

# %%
two_blobs_outliers = pd.read_csv(r'D:\Data Science\udemy\Notebooks\DATA\cluster_two_blobs_outliers.csv')

# %%
two_blobs_outliers
# Out:
#             X1        X2
# 0     0.046733  1.765120
# 1    -8.994134 -6.508186
# 2     0.650539  1.264533
# 3    -9.501554 -6.736493
# 4     0.057050  0.188215
# ...        ...       ...
# 998   0.954444  0.889178
# 999  -8.867767 -5.635758
# 1000 -4.000000 -2.000000
# 1001  0.000000 -8.000000
# 1002 -8.000000  0.000000
#
# [1003 rows x 2 columns]

# %%
sns.scatterplot(data = two_blobs, x = 'X1',y='X2')
plt.show()

# %%
sns.scatterplot(data = two_blobs_outliers, x = 'X1',y='X2')
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN()

# %%
def display_categories(model, data):
    labels = model.fit_predict(data)
    sns.scatterplot(data = data, x='X1', y='X2', hue=labels, palette = 'Set1')

# %%
display_categories(dbscan, two_blobs)

# %%
display_categories(dbscan, two_blobs_outliers)

# %%
dbscan = DBSCAN(eps=0.001)
display_categories(dbscan, two_blobs_outliers)

# %%
dbscan = DBSCAN(eps=10)
display_categories(dbscan, two_blobs_outliers)

# %%
dbscan = DBSCAN(eps=1)
display_categories(dbscan, two_blobs_outliers)

# %%
np.sum(dbscan.labels_ == -1)
# Out:
# 3

# %%
np.sum(dbscan.labels_ == -1) * 100 / len(dbscan.labels_)
# Out:
# 0.29910269192422734

# %%
outlier_per = list()

# %%
num_of_out = list()

# %%
for i in np.arange(1, 100):
    dbscan = DBSCAN(eps=i)
    dbscan.fit(two_blobs_outliers)
    num_of_out.append(np.sum(dbscan.labels_ == -1))
    outlier_per.append(np.sum(dbscan.labels_ == -1) * 100 / len(dbscan.labels_))

# %%
sns.lineplot(x=np.linspace(0.001, 10, 200), y = num_of_out)
plt.xlim(0, 2)
plt.ylim(0, 10)
plt.hlines(y=3, xmin = 0, xmax = 2, color = 'red')
plt.show()

# %%
sns.lineplot(x=np.linspace(0.001, 10, 200), y = outlier_per)
plt.xlim(0, 2)
plt.show()

# %%
dbscan = DBSCAN(eps=0.75)
display_categories(dbscan, two_blobs_outliers)

# %%
sns.lineplot(x = np.arange(1, 100), y = outlier_per)
plt.show()

# %%
outlier_per = list()
num_of_out = list()
for i in np.arange(1, 100):
    dbscan = DBSCAN(min_samples=i)
    dbscan.fit(two_blobs_outliers)
    num_of_out.append(np.sum(dbscan.labels_ == -1))
    outlier_per.append(np.sum(dbscan.labels_ == -1) * 100 / len(dbscan.labels_))

# %%
sns.lineplot(x=np.arange(1, 100), y = outlier_per)
# Out:
# <AxesSubplot: >

# %%
num_dim = two_blobs_outliers.shape[1]
dbscan = DBSCAN(min_samples = 2*num_dim,eps=0.75)
display_categories(dbscan, two_blobs_outliers)
